# %%
# Read SoCal Ozone Table
import pandas as pd
from scipy import stats
import numpy as np
import matplotlib.pyplot as plt

# %%
#Note Don't run this cell if in ArcGIS Pro (or delete it)
# %matplotlib inline

# %%
LAXOZData = pd.read_excel('Chapter11.xlsx', sheet_name=3) 
LAXOZData
# Out:
#          Date  7:00AM  3:00PM  9:00PM
# 0  2014-07-01   0.030   0.040   0.036
# 1  2014-07-02   0.027   0.042   0.037
# 2  2014-07-03   0.025   0.053   0.033
# 3  2014-07-05   0.019   0.044   0.022
# 4  2014-07-06   0.023   0.034   0.033
# 5  2014-07-07   0.017   0.031   0.022
# 6  2014-07-08   0.020   0.042   0.025
# 7  2014-07-09   0.026   0.046   0.031
# 8  2014-07-10   0.023   0.045   0.030
# 9  2014-07-11   0.021   0.042   0.022
# 10 2014-07-12   0.023   0.031   0.026
# 11 2014-07-13   0.025   0.036   0.023
# 12 2014-07-14   0.020   0.044   0.024
# 13 2014-07-15   0.017   0.035   0.020
# 14 2014-07-16   0.019   0.025   0.026
# 15 2014-07-17   0.023   0.031   0.024
# 16 2014-07-18   0.012   0.025   0.015
# 17 2014-07-19   0.022   0.026   0.020
# 18 2014-07-20   0.019   0.023   0.021
# 19 2014-07-21   0.014   0.033   0.017
# 20 2014-07-22   0.013   0.031   0.016
# 21 2014-07-23   0.009   0.031   0.002
# 22 2014-07-24   0.011   0.033   0.006
# 23 2014-07-25   0.026   0.037   0.014
# ...

# %%
boxplot = LAXOZData.boxplot()
plt.show()

# %%
LAXOZData.describe()
# Out:
#           7:00AM     3:00PM     9:00PM
# count  28.000000  28.000000  28.000000
# mean    0.019786   0.036893   0.022643
# std     0.005181   0.007814   0.008685
# min     0.009000   0.023000   0.002000
# 25%     0.016750   0.031000   0.019250
# 50%     0.020000   0.036000   0.022500
# 75%     0.023000   0.044000   0.027000
# max     0.030000   0.053000   0.037000

# %%
stats.f_oneway(LAXOZData[['7:00AM']], LAXOZData[['3:00PM']], LAXOZData[['9:00PM']])
# Out:
# F_onewayResult(statistic=array([43.19147196]), pvalue=array([1.71135295e-13]))
