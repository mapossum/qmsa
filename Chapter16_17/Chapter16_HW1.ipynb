# %%
import pandas as pd
from scipy import stats
import numpy as np
import matplotlib.pyplot as plt

# %%
PvtyTAMData = pd.read_excel('Chapter16_17.xlsx', sheet_name=0) 
PvtyTAMData
# Out:
#                    State  Births to teenage mothers  Poverty Rate
# 0                Alabama                       13.4          16.7
# 1                 Alaska                        9.8          10.0
# 2                Arizona                       11.9          15.2
# 3               Arkansas                       14.6          15.9
# 4             California                        9.2          13.2
# 5               Colorado                        9.1          11.4
# 6            Connecticut                        6.8           9.7
# 7               Delaware                        9.5           9.2
# 8   District of Columbia                       11.7          20.7
# 9                Florida                       10.1          11.1
# 10               Georgia                       11.7          14.4
# 11                Hawaii                        8.3           8.6
# 12                 Idaho                        8.6           9.9
# ...

# %%
ax1 = PvtyTAMData.plot.scatter(x="Poverty Rate",y="Births to teenage mothers",c='DarkBlue', figsize=(10,10))

# %%
r, pvalue = stats.pearsonr(PvtyTAMData["Poverty Rate"], PvtyTAMData["Births to teenage mothers"])
print("r:", r)
print("pvalue:", pvalue)
# Out:
# r: 0.8450153288428301
# pvalue: 6.360439842872893e-15
