# %%
import pandas as pd
from scipy import stats
import numpy as np
import matplotlib.pyplot as plt

# %%
TaxTable = pd.read_excel('Chapter16_17.xlsx', sheet_name=1) 
TaxTable
# Out:
#              State  State Income Tax  Highest Corporate Tax Rate  \
# 0          Alabama             5.000                       6.500
# 1           Alaska             0.000                       9.400
# 2          Arizona             4.540                       6.968
# 3         Arkansas             7.000                       6.500
# 4       California            12.300                       8.840
# 5         Colorado             4.300                       4.630
# 6      Connecticut             6.700                       9.000
# 7         Delaware             6.600                       8.700
# 8          Florida             0.000                       5.500
# 9          Georgia             6.000                       6.000
# 10          Hawaii            11.000                       6.400
# 11           Idaho             7.400                       7.400
# 12        Illinois             5.400                       9.500
# ...

# %%
ax1 = TaxTable.plot.scatter(x="State Income Tax",y="Unemployment Rate (July 2014)",c='DarkBlue', figsize=(10,10))

# %%
r, pvalue = stats.pearsonr(TaxTable["State Income Tax"], TaxTable["Unemployment Rate (July 2014)"])
print("r:", r)
print("pvalue:", pvalue)
# Out:
# r: 0.08480624750120934
# pvalue: 0.5581713496349994
