# %%
import pandas as pd
bbTable = pd.read_excel('../data/workbook-data-v2.xlsx', "Chapter 4 - Baseball Teams") 
bbTable
# Out:
#      Decade        Team   State  Latitude  Longitude           LAX  \
# 0      1900      Boston      MA  42.35866   -71.0567 -5.672072e+06
# 1      1900    Brooklyn      NY  40.69245   -73.9904 -5.988863e+06
# 2      1900     Chicago      IL  41.88425   -87.6324 -6.621766e+06
# 3      1900  Cincinnati      OH  39.10713   -84.5041 -6.733336e+06
# 4      1900    New York      NY  40.78200   -73.8317 -5.971781e+06
# ..      ...         ...     ...       ...        ...           ...
# 137    2010   St. Louis      MO  38.62775   -90.1996 -7.068501e+06
# 138    2010   Tampa Bay      FL  27.58300   -82.6330 -7.520205e+06
# 139    2010       Tempe      AZ  33.42551  -111.9370 -8.431611e+06
# 140    2010     Toronto  Canada  43.65740   -79.4328 -6.039826e+06
# 141    2010  Washington      DC  38.89037   -77.0320 -6.322856e+06
#
#               LAY
# 0    5.431360e+06
# 1    5.321796e+06
# 2    5.903381e+06
# 3    5.461898e+06
# 4    5.327672e+06
# ..            ...
# 137  5.610546e+06
# ...

# %%
gbb = bbTable.groupby("Decade").agg("mean")
gbb
# Out:
#          Latitude  Longitude           LAX           LAY
# Decade
# 1900    40.480357 -79.546863 -6.317860e+06  5.474649e+06
# 1920    40.635912 -79.751781 -6.314774e+06  5.498769e+06
# 1940    40.635912 -79.751781 -6.314774e+06  5.498769e+06
# 1960    40.064213 -86.971987 -6.663507e+06  5.740002e+06
# 1980    39.338697 -91.991654 -6.900636e+06  5.864837e+06
# 2000    38.485363 -92.402903 -6.999486e+06  5.771202e+06
# 2010    38.179712 -92.490617 -7.027354e+06  5.738002e+06

# %%
farmsTable = pd.read_excel('../data/workbook-data-v2.xlsx', "Chapter 4 - Population and Farm") 
farmsTable
# Out:
#                      Province  Longitude  Latitude  \
# 0                     Alberta  -115.0001   55.2774
# 1            British Columbia  -126.5532   55.4615
# 2                    Manitoba   -95.4932   54.5000
# 3               New Brunswick   -66.4126   46.5598
# 4   Newfoundland and Labrador   -61.7180   54.1040
# 5       Northwest Territories  -119.2344   63.6916
# 6                 Nova Scotia   -63.5866   44.9918
# 7                     Nunavut  -100.9561   63.8763
# 8                     Ontario   -84.7488   51.3402
# 9        Prince Edward Island   -63.1921   46.2951
# 10                     Quebec   -68.4333   53.9297
# 11               Saskatchewan  -105.6850   54.5000
# 12                      Yukon  -132.4037   62.3897
#
#     Population 2013 (in  thousands)  Number of Farms, 2004
# 0                            4025.1                  53652
# 1                            4582.0                  20290
# 2                            1265.0                  21071
# ...

# %%
unweighted = farmsTable.agg("mean")
unweighted
# Out:
# Longitude                            -92.570546
# Latitude                              54.378238
# Population 2013 (in  thousands)     2704.484615
# Number of Farms, 2004              19047.692308
# dtype: float64
