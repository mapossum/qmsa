# %%
import pandas as pd
import numpy as np
from arcgis.features import GeoAccessor, GeoSeriesAccessor
import matplotlib.pyplot as plt
from scipy import stats

sdf = pd.DataFrame.spatial.from_featureclass("Chapter12.gdb\GenerateTessellation_Spatial")
sdf = sdf[sdf['Join_Count'] < 12]
sdf
# Out:
#      OBJECTID  Join_Count                                              SHAPE
# 0           1           5  {'rings': [[[523239.2592000002, 1050821.365499...
# 2          10           2  {'rings': [[[523239.2592000002, 1068114.892200...
# 3          11           9  {'rings': [[[538215.8926999997, 1059468.128799...
# 4          12           7  {'rings': [[[553192.5261000004, 1068114.892200...
# 7          16           7  {'rings': [[[613099.0599999996, 1068114.892200...
# ..        ...         ...                                                ...
# 536       545           6  {'rings': [[[538215.8926999997, 1578273.930500...
# 537       546           1  {'rings': [[[568169.1595999999, 1578273.930500...
# 538       547           3  {'rings': [[[598122.4265000001, 1578273.930500...
# 539       548           2  {'rings': [[[628075.6935, 1578273.9305000007],...
# 540       549           1  {'rings': [[[658028.9604000002, 1578273.930500...
#
# [517 rows x 3 columns]

# %%
tornadoCount = sdf.groupby(['Join_Count']).count()
tornadoCount
# Out:
#             OBJECTID  SHAPE
# Join_Count
# 0                 31     31
# 1                 51     51
# 2                 96     96
# 3                 75     75
# 4                 69     69
# 5                 57     57
# 6                 38     38
# 7                 38     38
# 8                 24     24
# 9                 19     19
# 10                15     15
# 11                 4      4

# %%
tornadoCount = tornadoCount.reset_index()
tornadoCount['Observed'] = tornadoCount['OBJECTID']
tornadoCount = tornadoCount.drop(columns=['OBJECTID', 'SHAPE'])
lam = sdf['Join_Count'].mean()
tornadoCount['Expected'] = stats.poisson.pmf(tornadoCount['Join_Count'],lam) * sdf['Join_Count'].count()
tornadoCount
# Out:
#     Join_Count  Observed    Expected
# 0            0        31    9.251929
# 1            1        51   37.222460
# 2            2        96   74.876902
# 3            3        75  100.415188
# 4            4        69  100.997868
# 5            5        57   81.267143
# 6            6        38   54.492475
# 7            7        38   31.319245
# 8            8        24   15.750491
# 9            9        19    7.040838
# 10          10        15    2.832678
# 11          11         4    1.036042

# %%
plotTornadoCount = tornadoCount.set_index("Join_Count")[['Observed', 'Expected']]
ax = plotTornadoCount.plot.bar(rot=0)

# %%
plotTornadoCount["ChiSqContrib"] = (plotTornadoCount['Observed'] - plotTornadoCount['Expected'])**2 / plotTornadoCount['Expected']
plotTornadoCount
# Out:
#             Observed    Expected  ChiSqContrib
# Join_Count
# 0                 31    9.251929     51.122162
# 1                 51   37.222460      5.099626
# 2                 96   74.876902      5.958917
# 3                 75  100.415188      6.432610
# 4                 69  100.997868     10.137477
# 5                 57   81.267143      7.246400
# 6                 38   54.492475      4.991547
# 7                 38   31.319245      1.425082
# 8                 24   15.750491      4.320780
# 9                 19    7.040838     20.313142
# 10                15    2.832678     52.262822
# 11                 4    1.036042      8.479434

# %%
stats.chisquare(tornadoCount['Observed'], f_exp=tornadoCount['Expected'])
# Out:
# Power_divergenceResult(statistic=177.7899990831424, pvalue=2.92938442080316e-32)
