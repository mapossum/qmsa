# %%
import pandas as pd
dataframe = pd.read_excel('https://github.com/mapossum/qmsa/blob/master/data/workbook-data-v2.xlsx?raw=true',sheet_name=1)
dataframe
# Out:
#                          NAME  Electric Consumption (KWH)  \
# 0                 Afghanistan                     2489.00
# 1                      Angola                     4592.00
# 2                     Albania                     4551.00
# 3        United Arab Emirates                    85170.00
# 4                   Argentina                   111100.00
# 5                     Armenia                     5800.00
# 6                   Australia                   213500.00
# 7                     Austria                    63800.00
# 8                  Azerbaijan                    20290.00
# 9                     Burundi                      221.40
# 10                    Belgium                    84680.00
# 11                      Benin                      870.10
# 12               Burkina Faso                      773.10
# 13                 Bangladesh                    38890.00
# 14                   Bulgaria                    30460.00
# ...
