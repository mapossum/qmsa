# %%
import pandas as pd
df = pd.read_excel('https://github.com/mapossum/qmsa/blob/master/data/bookData/Chapter1/Life_Expectancy_at_the_Country_and_World_Region_Levels/Life_Expectancy_and_Per_Capita_Health_Care_Expeditures.xls?raw=true',sheet_name=2)
df
# Out:
#             Country Abbrev  Years  US_PPP
# 0        Australia     AUS   81.5    3445
# 1           Austria    AUT   80.4    4289
# 2           Belgium    BEL   80.0    3946
# 3            Brazil    BRA   72.6     943
# 4           Canada     CAN   80.7    3844
# 5             Chile    CHL   78.4    1186
# 6            China     CHN   73.3     308
# 7    Czech Republic    CZE   77.3    2108
# 8           Denmark    DNK   79.0    4348
# 9           Estonia    EST   75.0    1393
# 10          Finland    FIN   80.0    3226
# 11           France    FRA   81.0    3978
# 12          Germany    DEU   80.3    4218
# 13          Greece     GRC   79.5    2724
# 14          Hungary    HUN   74.0    1511
# 15          Iceland    ISL   81.5    3538
# 16           India     IND   64.1     132
# 17       Indonesia     IDN   71.2      99
# 18          Ireland    IRL   80.0    3781
# 19           Israel    ISR   81.6    2164
# 20           Italy     ITA   81.8    3059
# ...

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

y = df["Years"]
x = df["US_PPP"]

plt.scatter(x, y)
plt.show()

# %%
fig, ax = plt.subplots()
hist = ax.hist(x, bins=10)

# %%
fig, ax = plt.subplots()
hist = ax.hist(y, bins=10)

# %%
fig, ax = plt.subplots()
hist = ax.hist2d(x, y, bins=10)

# %%
np.histogram2d(x, y, bins=(5, 5))
# Out:
# (array([[ 1.,  2.,  5.,  3.,  0.],
#         [ 0.,  0.,  1.,  1., 10.],
#         [ 0.,  0.,  0.,  0., 12.],
#         [ 0.,  0.,  0.,  0.,  3.],
#         [ 0.,  0.,  0.,  1.,  0.]]),
#  array([  99. , 1671.2, 3243.4, 4815.6, 6387.8, 7960. ]),
#  array([64.1 , 67.82, 71.54, 75.26, 78.98, 82.7 ]))
